# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline
import warnings     #To ignore warnings
warnings.filterwarnings("ignore")
data_full=pd.read_csv("/Users/manaschakraborty/Library/Mobile Documents/com~apple~Numbers/Documents/DataCoSupplyChainDataset2.csv")
data_full.head()
# Out:
#        Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0     DEBIT                         3                              4
# 1  TRANSFER                         5                              4
# 2      CASH                         4                              4
# 3     DEBIT                         3                              4
# 4   PAYMENT                         2                              4
#
#    Benefit per order  Sales per customer   Delivery Status  \
# 0          91.250000          314.640015  Advance shipping
# 1        -249.089996          311.359985     Late delivery
# 2        -247.779999          309.720001  Shipping on time
# 3          22.860001          304.809998  Advance shipping
# 4         134.210007          298.250000  Advance shipping
#
#    Late_delivery_risk  Category Id   Category Name Customer City  ...  \
# 0                   0           73  Sporting Goods        Caguas  ...
# ...

# %%
data_full.columns
# Out:
# Index(['Type', 'Days for shipping (real)', 'Days for shipment (scheduled)',
#        'Benefit per order', 'Sales per customer', 'Delivery Status',
#        'Late_delivery_risk', 'Category Id', 'Category Name', 'Customer City',
#        'Customer Country', 'Customer Email', 'Customer Fname', 'Customer Id',
#        'Customer Lname', 'Customer Password', 'Customer Segment',
#        'Customer State', 'Customer Street', 'Customer Zipcode',
#        'Department Id', 'Department Name', 'Latitude', 'Longitude', 'Market',
#        'Order City', 'Order Country', 'Order Customer Id',
#        'order date (DateOrders)', 'Order Id', 'Order Item Cardprod Id',
#        'Order Item Discount', 'Order Item Discount Rate', 'Order Item Id',
#        'Order Item Product Price', 'Order Item Profit Ratio',
#        'Order Item Quantity', 'Sales', 'Order Item Total',
#        'Order Profit Per Order', 'Order Region', 'Order State', 'Order Status',
# ...

# %%
data_full.duplicated().sum()
# Out:
# 0

# %%
data_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65534 entries, 0 to 65533
# Data columns (total 53 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Type                           65534 non-null  object
#  1   Days for shipping (real)       65534 non-null  int64
#  2   Days for shipment (scheduled)  65534 non-null  int64
#  3   Benefit per order              65534 non-null  float64
#  4   Sales per customer             65534 non-null  float64
#  5   Delivery Status                65534 non-null  object
#  6   Late_delivery_risk             65534 non-null  int64
#  7   Category Id                    65534 non-null  int64
#  8   Category Name                  65534 non-null  object
#  9   Customer City                  65534 non-null  object
#  10  Customer Country               65534 non-null  object
#  11  Customer Email                 65534 non-null  object
# ...

# %%
data_full.describe()
# Out:
#        Days for shipping (real)  Days for shipment (scheduled)  \
# count              65534.000000                   65534.000000
# mean                   3.422666                       2.802622
# std                    1.631240                       1.402022
# min                    0.000000                       0.000000
# 25%                    2.000000                       2.000000
# 50%                    3.000000                       4.000000
# 75%                    5.000000                       4.000000
# max                    6.000000                       4.000000
#
#        Benefit per order  Sales per customer  Late_delivery_risk  \
# count       65534.000000        65534.000000        65534.000000
# mean           21.346697          175.972695            0.581057
# std           103.758815          122.301810            0.493390
# min         -4274.979980            7.490000            0.000000
# 25%             6.150000          100.779999            0.000000
# ...

# %%
country_data=data_full[["Order City","Order Country","Order Region"]]
country_data.head(10)
# Out:
#    Order City Order Country    Order Region
# 0      Bekasi     Indonesia  Southeast Asia
# 1     Bikaner         India      South Asia
# 2     Bikaner         India      South Asia
# 3  Townsville     Australia         Oceania
# 4  Townsville     Australia         Oceania
# 5   Toowoomba     Australia         Oceania
# 6   Guangzhou         China    Eastern Asia
# 7   Guangzhou         China    Eastern Asia
# 8   Guangzhou         China    Eastern Asia
# 9   Guangzhou         China    Eastern Asia

# %%
indian_data=data_full.loc[data_full["Order Country"]=="India"]
indian_data2=indian_data.loc[indian_data["Order Status"]=="PENDING"]
data2=indian_data2[["Order City","Order Status"]]
data2.head(50)
# Out:
#         Order City Order Status
# 1          Bikaner      PENDING
# 21        Jabalpur      PENDING
# 45       Bangalore      PENDING
# 46       Bangalore      PENDING
# 382           Pune      PENDING
# 708         Jaipur      PENDING
# 1024        Ranchi      PENDING
# 1031          Durg      PENDING
# 1054          Durg      PENDING
# 1161         Patna      PENDING
# 1163         Patna      PENDING
# 1167     Faridabad      PENDING
# 1236      Fatehpur      PENDING
# 1279          Kota      PENDING
# 1831      Guwahati      PENDING
# 2565        Rohtak      PENDING
# 2568        Mumbai      PENDING
# 2757         Kulti      PENDING
# 2759        Imphal      PENDING
# 5004     Gorakhpur      PENDING
# 5026     Bangalore      PENDING
# 5338         Patna      PENDING
# 5360       Lucknow      PENDING
# 10191      Lucknow      PENDING
# 10866        Patna      PENDING
# 10873        Hubli      PENDING
# 10886       Nagpur      PENDING
# 10889        Ajmer      PENDING
# ...

# %%
data2.tail()
# Out:
#        Order City Order Status
# 52569       Ajmer      PENDING
# 52617    Jamnagar      PENDING
# 62400  Puducherry      PENDING
# 62418      Ranchi      PENDING
# 62424     Lucknow      PENDING

# %%
data2.tail(50)
# Out:
#         Order City Order Status
# 11447       Raipur      PENDING
# 11608        Thane      PENDING
# 11611        Dewas      PENDING
# 17123  Tirunelveli      PENDING
# 17125         Pune      PENDING
# 17131    Bangalore      PENDING
# 17148       Mumbai      PENDING
# 17149    Darbhanga      PENDING
# 17160    Gorakhpur      PENDING
# 17174      Aligarh      PENDING
# 17182      Lucknow      PENDING
# 17187      Lucknow      PENDING
# 17193   Saharanpur      PENDING
# 30434     Vadodara      PENDING
# 30449        Delhi      PENDING
# 30451        Delhi      PENDING
# 30462       Bhopal      PENDING
# 30478       Imphal      PENDING
# 30484      Jodhpur      PENDING
# 30491       Raipur      PENDING
# 30813        Delhi      PENDING
# 30815       Kanpur      PENDING
# 31003        Ajmer      PENDING
# 31004        Ajmer      PENDING
# 31010       Imphal      PENDING
# 31188       Kanpur      PENDING
# 31376        Ajmer      PENDING
# 31381     Jabalpur      PENDING
# ...

# %%
data2[50:100]
# Out:
#        Order City Order Status
# 30815      Kanpur      PENDING
# 31003       Ajmer      PENDING
# 31004       Ajmer      PENDING
# 31010      Imphal      PENDING
# 31188      Kanpur      PENDING
# 31376       Ajmer      PENDING
# 31381    Jabalpur      PENDING
# 31384   Gorakhpur      PENDING
# 31390     Jodhpur      PENDING
# 32020   Moradabad      PENDING
# 32032   Bangalore      PENDING
# 32034    Guwahati      PENDING
# 32354      Kanpur      PENDING
# 32715   Moradabad      PENDING
# 32722    Guwahati      PENDING
# 32741       Delhi      PENDING
# 32742     Belgaum      PENDING
# 50955   Hyderabad      PENDING
# 52196     Jodhpur      PENDING
# 52420     Nellore      PENDING
# 52421     Nellore      PENDING
# 52434      Jaipur      PENDING
# 52513       Korba      PENDING
# 52542      Mumbai      PENDING
# 52569       Ajmer      PENDING
# 52617    Jamnagar      PENDING
# 62400  Puducherry      PENDING
# 62418      Ranchi      PENDING
# 62424     Lucknow      PENDING

# %%
data2.tail(100)
# Out:
#        Order City Order Status
# 1         Bikaner      PENDING
# 21       Jabalpur      PENDING
# 45      Bangalore      PENDING
# 46      Bangalore      PENDING
# 382          Pune      PENDING
# ...           ...          ...
# 52569       Ajmer      PENDING
# 52617    Jamnagar      PENDING
# 62400  Puducherry      PENDING
# 62418      Ranchi      PENDING
# 62424     Lucknow      PENDING
#
# [79 rows x 2 columns]

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 79 entries, 1 to 62424
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order City    79 non-null     object
#  1   Order Status  79 non-null     object
# dtypes: object(2)
# memory usage: 1.9+ KB

# %%
data3=data_full.loc[data_full["Order Status"]=="SUSPECTED_FRAUD"]
fraud_data=data3[["Order Country","Order Status"]]
fraud_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 718 entries, 10 to 62552
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order Country  718 non-null    object
#  1   Order Status   718 non-null    object
# dtypes: object(2)
# memory usage: 16.8+ KB

# %%
fraud_data.head(20)
# Out:
#       Order Country     Order Status
# 10            Japón  SUSPECTED_FRAUD
# 24        Australia  SUSPECTED_FRAUD
# 183  Estados Unidos  SUSPECTED_FRAUD
# 184  Estados Unidos  SUSPECTED_FRAUD
# 185  Estados Unidos  SUSPECTED_FRAUD
# 186  Estados Unidos  SUSPECTED_FRAUD
# 187  Estados Unidos  SUSPECTED_FRAUD
# 188  Estados Unidos  SUSPECTED_FRAUD
# 189  Estados Unidos  SUSPECTED_FRAUD
# 190  Estados Unidos  SUSPECTED_FRAUD
# 191  Estados Unidos  SUSPECTED_FRAUD
# 192          Canada  SUSPECTED_FRAUD
# 193  Estados Unidos  SUSPECTED_FRAUD
# 194          Canada  SUSPECTED_FRAUD
# 195          Canada  SUSPECTED_FRAUD
# 196  Estados Unidos  SUSPECTED_FRAUD
# 197  Estados Unidos  SUSPECTED_FRAUD
# 198  Estados Unidos  SUSPECTED_FRAUD
# 395           China  SUSPECTED_FRAUD
# 407           India  SUSPECTED_FRAUD

# %%
fraud_data.tail()
# Out:
#         Order Country     Order Status
# 62473           China  SUSPECTED_FRAUD
# 62549  Estados Unidos  SUSPECTED_FRAUD
# 62550  Estados Unidos  SUSPECTED_FRAUD
# 62551  Estados Unidos  SUSPECTED_FRAUD
# 62552  Estados Unidos  SUSPECTED_FRAUD

# %%
fraud_data[500:550]
# Out:
#                          Order Country     Order Status
# 31212                            India  SUSPECTED_FRAUD
# 31240                   Estados Unidos  SUSPECTED_FRAUD
# 31241                   Estados Unidos  SUSPECTED_FRAUD
# 31258  República Democrática del Congo  SUSPECTED_FRAUD
# 31310                          Francia  SUSPECTED_FRAUD
# 31311                            Suiza  SUSPECTED_FRAUD
# 31365                            Haití  SUSPECTED_FRAUD
# 31366                        Venezuela  SUSPECTED_FRAUD
# 31367                           Brasil  SUSPECTED_FRAUD
# 31414                            India  SUSPECTED_FRAUD
# 31415                            India  SUSPECTED_FRAUD
# 31416                        Australia  SUSPECTED_FRAUD
# 31442                   Estados Unidos  SUSPECTED_FRAUD
# 31443                   Estados Unidos  SUSPECTED_FRAUD
# 31444                   Estados Unidos  SUSPECTED_FRAUD
# 31445                   Estados Unidos  SUSPECTED_FRAUD
# ...

# %%
fraud_data[300:350]
# Out:
#                          Order Country     Order Status
# 11545                           Brasil  SUSPECTED_FRAUD
# 11546                         Colombia  SUSPECTED_FRAUD
# 11547                         Colombia  SUSPECTED_FRAUD
# 11548                         Colombia  SUSPECTED_FRAUD
# 11561                            India  SUSPECTED_FRAUD
# 11562                        Indonesia  SUSPECTED_FRAUD
# 11573                          Nigeria  SUSPECTED_FRAUD
# 11590                           España  SUSPECTED_FRAUD
# 11591                          Austria  SUSPECTED_FRAUD
# 11622                        Indonesia  SUSPECTED_FRAUD
# 11623                            India  SUSPECTED_FRAUD
# 11627                   Estados Unidos  SUSPECTED_FRAUD
# 11643                           España  SUSPECTED_FRAUD
# 11672                            India  SUSPECTED_FRAUD
# 11679                   Estados Unidos  SUSPECTED_FRAUD
# 11704                         Alemania  SUSPECTED_FRAUD
# ...

# %%
fraud_data.value_counts()
# Out:
# Order Country   Order Status
# Estados Unidos  SUSPECTED_FRAUD    109
# Francia         SUSPECTED_FRAUD     70
# México          SUSPECTED_FRAUD     56
# Brasil          SUSPECTED_FRAUD     45
# Alemania        SUSPECTED_FRAUD     32
#                                   ...
# Noruega         SUSPECTED_FRAUD      1
# Pakistán        SUSPECTED_FRAUD      1
# Sudán           SUSPECTED_FRAUD      1
# Suecia          SUSPECTED_FRAUD      1
# Afganistán      SUSPECTED_FRAUD      1
# Length: 68, dtype: int64

# %%
data5=data_full.loc[data_full["Order Item Discount"]>=100]
maxdisc=data5[["Order Item Discount","Product Name",]]
maxdisc.head()
# Out:
#      Order Item Discount                         Product Name
# 129           112.489998  Brooks Women's Ghost 6 Running Shoe
# 155           105.000000                          Dell Laptop
# 160           135.000000                          Dell Laptop
# 172           300.000000                          Dell Laptop
# 173           113.010002                           Web Camera

# %%
maxdisc.head(50)
# Out:
#       Order Item Discount                               Product Name
# 129            112.489998        Brooks Women's Ghost 6 Running Shoe
# 155            105.000000                                Dell Laptop
# 160            135.000000                                Dell Laptop
# 172            300.000000                                Dell Laptop
# 173            113.010002                                 Web Camera
# 697            124.989998          Nike Men's Free 5.0+ Running Shoe
# 931            124.989998          Nike Men's Free 5.0+ Running Shoe
# 932            124.989998          Nike Men's Free 5.0+ Running Shoe
# 933            124.989998          Nike Men's Free 5.0+ Running Shoe
# 934            124.989998          Nike Men's Free 5.0+ Running Shoe
# 1353           270.000000                                Dell Laptop
# 1370           225.000000                                Dell Laptop
# 1375           255.000000                                Dell Laptop
# ...

# %%
maxdisc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 430 entries, 129 to 65171
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Order Item Discount  430 non-null    float64
#  1   Product Name         430 non-null    object
# dtypes: float64(1), object(1)
# memory usage: 10.1+ KB

# %%
maxdisc.value_counts()
# Out:
# Order Item Discount  Product Name
# 100.000000           Field & Stream Sportsman 16 Gun Fire Safe    148
# 124.989998           Nike Men's Free 5.0+ Running Shoe             78
# 113.010002           Web Camera                                    22
# 255.000000           Dell Laptop                                   17
# 240.000000           Dell Laptop                                   17
# 270.000000           Dell Laptop                                   16
# 135.000000           Dell Laptop                                   15
# 300.000000           Dell Laptop                                   12
# 115.370003           Porcelain crafts                              12
# 150.000000           Dell Laptop                                   12
# 133.149994           Lawn mower                                    11
# 105.000000           Dell Laptop                                   11
# 180.000000           Dell Laptop                                   11
# ...

# %%
data6=data_full.loc[data_full["Order Status"]=="COMPLETE"]
successdata=data6[["Days for shipping (real)","Days for shipment (scheduled)","Order Status"]]
successdata.head(10)
# Out:
#     Days for shipping (real)  Days for shipment (scheduled) Order Status
# 0                          3                              4     COMPLETE
# 3                          3                              4     COMPLETE
# 6                          2                              1     COMPLETE
# 13                         2                              1     COMPLETE
# 15                         2                              1     COMPLETE
# 18                         2                              1     COMPLETE
# 25                         6                              2     COMPLETE
# 28                         3                              4     COMPLETE
# 31                         5                              4     COMPLETE
# 33                         2                              1     COMPLETE

# %%
successdata["Days for shipping (real)"] > successdata["Days for shipment (scheduled)"]
# Out:
# 0        False
# 3        False
# 6         True
# 13        True
# 15        True
#          ...
# 65529     True
# 65530     True
# 65531     True
# 65532     True
# 65533     True
# Length: 26700, dtype: bool

# %%
successdata.value_counts()
# Out:
# Days for shipping (real)  Days for shipment (scheduled)  Order Status
# 2                         1                              COMPLETE        4684
#                           4                              COMPLETE        2962
# 3                         4                              COMPLETE        2855
# 5                         4                              COMPLETE        2801
# 4                         4                              COMPLETE        2799
# 6                         4                              COMPLETE        2780
# 3                         2                              COMPLETE        1334
# 4                         2                              COMPLETE        1296
# 2                         2                              COMPLETE        1241
# 6                         2                              COMPLETE        1211
# 5                         2                              COMPLETE        1080
# ...

# %%
successdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26700 entries, 0 to 65533
# Data columns (total 3 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Days for shipping (real)       26700 non-null  int64
#  1   Days for shipment (scheduled)  26700 non-null  int64
#  2   Order Status                   26700 non-null  object
# dtypes: int64(2), object(1)
# memory usage: 834.4+ KB

# %%
successdata2=successdata.loc[successdata["Days for shipping (real)"]>successdata["Days for shipment (scheduled)"]]
successdata2.head(20)
# Out:
#      Days for shipping (real)  Days for shipment (scheduled) Order Status
# 6                           2                              1     COMPLETE
# 13                          2                              1     COMPLETE
# 15                          2                              1     COMPLETE
# 18                          2                              1     COMPLETE
# 25                          6                              2     COMPLETE
# 31                          5                              4     COMPLETE
# 33                          2                              1     COMPLETE
# 37                          2                              1     COMPLETE
# 38                          1                              0     COMPLETE
# 41                          1                              0     COMPLETE
# 145                         3                              2     COMPLETE
# 146                         4                              2     COMPLETE
# ...

# %%
successdata2[50:100]
# Out:
#      Days for shipping (real)  Days for shipment (scheduled) Order Status
# 253                         5                              4     COMPLETE
# 258                         6                              4     COMPLETE
# 263                         5                              4     COMPLETE
# 264                         5                              4     COMPLETE
# 269                         5                              4     COMPLETE
# 277                         6                              4     COMPLETE
# 279                         5                              4     COMPLETE
# 282                         6                              4     COMPLETE
# 283                         5                              4     COMPLETE
# 285                         6                              4     COMPLETE
# 286                         5                              4     COMPLETE
# 287                         6                              4     COMPLETE
# ...

# %%
successdata2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15960 entries, 6 to 65533
# Data columns (total 3 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Days for shipping (real)       15960 non-null  int64
#  1   Days for shipment (scheduled)  15960 non-null  int64
#  2   Order Status                   15960 non-null  object
# dtypes: int64(2), object(1)
# memory usage: 498.8+ KB

# %%
successdata2.value_counts()
# Out:
# Days for shipping (real)  Days for shipment (scheduled)  Order Status
# 2                         1                              COMPLETE        4684
# 5                         4                              COMPLETE        2801
# 6                         4                              COMPLETE        2780
# 3                         2                              COMPLETE        1334
# 4                         2                              COMPLETE        1296
# 6                         2                              COMPLETE        1211
# 5                         2                              COMPLETE        1080
# 1                         0                              COMPLETE         774
# dtype: int64
